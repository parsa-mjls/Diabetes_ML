# %% [markdown]
# # **K-means**
#
# **cluster : خوشه بندی**

# %%
from sklearn.datasets import make_blobs

X,Y = make_blobs(n_samples= 370 , n_features=2 , centers= 4)

# %%
Y
# Out:
# array([1, 1, 1, 3, 0, 1, 0, 1, 3, 3, 1, 2, 0, 2, 3, 3, 3, 1, 0, 2, 2, 0,
#        1, 1, 2, 1, 1, 3, 1, 0, 2, 1, 2, 1, 1, 2, 3, 1, 3, 1, 2, 1, 2, 0,
#        0, 0, 2, 1, 1, 3, 3, 1, 1, 2, 2, 3, 2, 1, 1, 0, 0, 0, 2, 3, 1, 0,
#        0, 3, 3, 1, 2, 2, 3, 0, 1, 1, 3, 0, 3, 2, 3, 0, 0, 3, 0, 2, 3, 2,
#        3, 3, 2, 2, 1, 3, 0, 2, 2, 3, 2, 0, 2, 2, 3, 3, 3, 3, 0, 1, 1, 0,
#        0, 0, 1, 0, 3, 1, 2, 1, 3, 1, 1, 2, 3, 2, 2, 1, 1, 3, 2, 2, 3, 2,
#        0, 1, 2, 1, 3, 1, 1, 3, 3, 1, 1, 3, 3, 2, 0, 0, 2, 3, 3, 0, 1, 1,
#        0, 3, 3, 2, 1, 1, 0, 0, 0, 0, 3, 1, 3, 0, 1, 2, 2, 0, 2, 0, 2, 1,
#        3, 1, 2, 1, 0, 1, 1, 2, 2, 3, 0, 3, 2, 2, 3, 3, 2, 2, 3, 1, 3, 0,
#        0, 0, 0, 0, 0, 0, 1, 2, 2, 3, 3, 3, 1, 3, 2, 0, 1, 0, 0, 1, 2, 1,
#        1, 2, 3, 2, 2, 3, 2, 0, 3, 0, 0, 0, 2, 1, 0, 0, 1, 2, 3, 0, 0, 0,
#        2, 2, 1, 2, 0, 0, 3, 1, 2, 1, 1, 3, 2, 1, 1, 3, 1, 1, 3, 3, 0, 3,
#        0, 0, 0, 0, 0, 3, 3, 3, 3, 0, 2, 0, 1, 0, 0, 3, 3, 2, 0, 2, 2, 1,
#        0, 2, 0, 1, 1, 3, 3, 3, 3, 0, 0, 2, 0, 3, 3, 3, 3, 1, 2, 0, 0, 3,
#        1, 3, 0, 2, 2, 2, 1, 2, 1, 1, 0, 2, 1, 2, 1, 0, 2, 3, 2, 0, 0, 1,
#        3, 3, 1, 0, 3, 3, 0, 3, 1, 0, 0, 2, 1, 2, 2, 3, 0, 0, 1, 3, 2, 1,
#        0, 1, 2, 2, 3, 0, 2, 2, 2, 3, 2, 2, 2, 1, 1, 1, 2, 0])

# %%
import matplotlib.pyplot as plt

plt.scatter( X[: ,0] , X[: , 1] , c= 'b')
plt.show()

# %%
from sklearn.cluster import KMeans

model = KMeans( n_clusters= 4)
model.fit(X)
# Out:
# KMeans(n_clusters=4)

# %%
centers =model.cluster_centers_ 
labels =model.labels_

# %%
plt.scatter( X[:, 0], X[:, 1], c= labels)
plt.scatter( centers[:, 0] , centers[:, 1], c="red", marker="*")
plt.show()
